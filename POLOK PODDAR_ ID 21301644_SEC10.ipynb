# %% [markdown]
# problem-2

# %%
t = input("text: ")
t = list(t.lower())
a = []
b = []

for i in t:
    if i not in b:
        b += [i]
        if t.count(i)%2 != 0:
            a += [i]

print(a)
# Out:
# text: Avada Kedavra
# ['a', ' ', 'k', 'e', 'r']

# %% [markdown]
# problem -1

# %%
p= int(input("Enter Days:"))
r=int((p*(2/7))+0.5)
print("He can read",r,"books")
p=["Tuesday","Saturday "]
for i in(1,r):
  if i%2==0:
    print("Book",i,"on Saturday")
  elif i%2!=0:
    print("Book",i,"on Tuesday")
